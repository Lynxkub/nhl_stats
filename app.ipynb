# %%
import pandas as pd

# %%
df = pd.read_csv('stats.csv')

# %%
df.head()
# Out:
#                              Name Team  Age Pos  GP   G   A    P  PIM   +/-  \
# Connor McDavid             Canada  EDM   24   F  80  44  79  123   45  28.0
# Jonathan Huberdeau         Canada  FLA   28   F  80  30  85  115   54  35.0
# Kirill Kaprizov            Russia  MIN   24   F  81  47  61  108   34  27.0
# Steven Stamkos             Canada  TBL   31   F  81  42  64  106   36  24.0
# J.T. Miller         United-States  VAN   28   F  80  32  67   99   47  15.0
#
#                     ...   G/GP   A/GP   P/GP  SHOTS    SH%   HITS    BS  \
# Connor McDavid      ...  0.550  0.988  1.538  314.0  14.0%   75.0  26.0
# Jonathan Huberdeau  ...  0.375  1.063  1.438  222.0  13.5%   99.0  28.0
# Kirill Kaprizov     ...  0.580  0.753  1.333  289.0  16.3%   73.0  29.0
# Steven Stamkos      ...  0.519  0.790  1.309  241.0  17.4%   93.0  31.0
# J.T. Miller         ...  0.400  0.838  1.238  206.0  15.5%  172.0  56.0
#
#                       FOW    FOL     FO%
# ...

# %%
df.shape
# Out:
# (864, 49)
